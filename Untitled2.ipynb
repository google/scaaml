# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjitha006/scaaml/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
import os
scaaml_path = '/content/drive/MyDrive/scaaml'  # <-- EDIT THIS PATH IF NEEDED
os.chdir(scaaml_path)
print(f"Current directory: {os.getcwd()}")


# !python3 -m venv my_env
# !source my_env/bin/activate

#numpy dependency problem
# !pip install pyserial

# !python3 -m pip install --require-hashes -r requirements.txt
# !python setup.py develop


"""
#for running using models already present
# !pip install nbclient
from nbclient import NotebookClient
from nbformat import read, write
# Path to the notebook you want to run
notebook_path = '/content/drive/MyDrive/scaaml/scaaml_intro/key_recovery_demo.ipynb'

# Load the notebook
with open(notebook_path) as f:
    nb = read(f, as_version=4)

# Run the notebook
client = NotebookClient(nb)
client.execute()"""



# !pip install configobj
# !pip uninstall numpy -y
# !pip install "numpy<=1.26.4"  # ChipWhisperer requires this
#train all 48
! python scaaml_intro/train.py --config "./scaaml_intro/config/stm32f415_tinyaes.json"
#!python ./scaaml_intro/train_and_recover_16bytes.py
#!python ./scaaml_intro/key_recovery.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Current directory: /content/drive/MyDrive/scaaml
# Error: Command '['/content/drive/MyDrive/scaaml/my_env/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# /bin/bash: line 1: source: my_env/bin/activate: is a directory
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/colorama-0.4.6-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/libusb1-3.3.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
